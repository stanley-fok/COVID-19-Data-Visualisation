# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import plotly.express as px

# %%
from plotly.subplots import make_subplots

# %%
from datetime import datetime

# %%
#Import first dataset
covid_df = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/COVID-19 Data Visualization Scotland/covid-19-totals-scotland.csv")

# %%
#Return first 10 rows
covid_df.head(10)
# Out:
#          Date  Tests  ConfirmedCases  Deaths
# 0  2020-01-24      2               0     0.0
# 1  2020-01-25      5               0     0.0
# 2  2020-01-26      6               0     0.0
# 3  2020-01-27      7               0     0.0
# 4  2020-01-28     11               0     0.0
# 5  2020-01-29     11               0     0.0
# 6  2020-01-30     16               0     0.0
# 7  2020-01-31     16               0     0.0
# 8  2020-02-01     16               0     0.0
# 9  2020-02-02     16               0     0.0

# %%
#allows us to learn the shape of object types of our data
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            191 non-null    object
#  1   Tests           191 non-null    int64
#  2   ConfirmedCases  191 non-null    int64
#  3   Deaths          190 non-null    float64
#  4   Active Cases    190 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 7.6+ KB

# %%
#Summary statistics for numerical columns in the dataframe
covid_df.describe()
# Out:
#                Tests  ConfirmedCases       Deaths
# count     191.000000      191.000000   190.000000
# mean   101935.015707     9188.753927  1240.405263
# std    116572.586704     7700.154638  1101.473251
# min         2.000000        0.000000     0.000000
# 25%      2604.000000       48.000000     0.000000
# 50%     51499.000000    10721.000000  1297.000000
# 75%    174298.500000    16892.500000  2447.750000
# max    363239.000000    18645.000000  2491.000000

# %%
#Import second dataset
vaccine_df = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/COVID-19 Data Visualization Scotland/Vaccine Data 1.csv")

# %%
vaccine_df.head(7)
# Out:
#    _id        Date    Country                      Product  Population  \
# 0    1  2020-12-08  S92000003      AstraZeneca (Vaxzevria)         NaN
# 1    2  2020-12-08  S92000003      AstraZeneca (Vaxzevria)         NaN
# 2    3  2020-12-08  S92000003      AstraZeneca (Vaxzevria)         NaN
# 3    4  2020-12-08  S92000003           Moderna (Spikevax)         NaN
# 4    5  2020-12-08  S92000003           Moderna (Spikevax)         NaN
# 5    6  2020-12-08  S92000003           Moderna (Spikevax)         NaN
# 6    7  2020-12-08  S92000003  Pfizer BioNTech (Comirnaty)         NaN
#
#      Dose  NumberVaccinated  PercentCoverage  CumulativeNumberVaccinated  \
# 0  Dose 1                14              NaN                          14
# 1  Dose 2                 0              NaN                           0
# 2  Dose 3                 0              NaN                           0
# 3  Dose 1                 0              NaN                           0
# 4  Dose 2                 0              NaN                           0
# 5  Dose 3                 0              NaN                           0
# 6  Dose 1              1934              NaN                        1934
#
#    CumulativePercentCoverage           AgeBand
# 0                        NaN  All vaccinations
# 1                        NaN  All vaccinations
# 2                        NaN  All vaccinations
# 3                        NaN  All vaccinations
# 4                        NaN  All vaccinations
# 5                        NaN  All vaccinations
# 6                        NaN  All vaccinations

# %%
#Generate active cases
covid_df["Active Cases"] = covid_df["ConfirmedCases"] + covid_df["Deaths"]
covid_df.tail()
# Out:
#            Date   Tests  ConfirmedCases  Deaths  Active Cases
# 186  2020-07-28  349223           18558  2491.0       21049.0
# 187  2020-07-29  352494           18580  2491.0       21071.0
# 188  2020-07-30  355898           18597  2491.0       21088.0
# 189  2020-07-31  359537           18627  2491.0       21118.0
# 190  2020-08-01  363239           18645     NaN           NaN

# %%
statewise = pd.pivot_table(covid_df, values = ["ConfirmedCases", "Deaths", "Tests"], index = "Date", aggfunc = max)

# %%
statewise["Mortality Rate"] = statewise["Deaths"]*100/statewise["ConfirmedCases"]

# %%
statewise = statewise.sort_values(by = "ConfirmedCases", ascending = False)

# %%
#cmap = colour map 
statewise.style.background_gradient(cmap = "cubehelix" )
# Out:
# <style type="text/css">
# #T_4559d_row0_col0, #T_4559d_row0_col2, #T_4559d_row1_col0, #T_4559d_row1_col1, #T_4559d_row2_col0, #T_4559d_row2_col1, #T_4559d_row3_col0, #T_4559d_row3_col1, #T_4559d_row4_col1, #T_4559d_row5_col1, #T_4559d_row6_col1, #T_4559d_row7_col1, #T_4559d_row8_col1, #T_4559d_row9_col1, #T_4559d_row10_col1, #T_4559d_row11_col1, #T_4559d_row12_col1, #T_4559d_row13_col1, #T_4559d_row14_col1, #T_4559d_row15_col1, #T_4559d_row16_col1, #T_4559d_row17_col1, #T_4559d_row18_col1, #T_4559d_row19_col1, #T_4559d_row20_col1, #T_4559d_row21_col1, #T_4559d_row22_col1, #T_4559d_row23_col1, #T_4559d_row24_col1, #T_4559d_row25_col1, #T_4559d_row26_col1, #T_4559d_row27_col1, #T_4559d_row28_col1, #T_4559d_row29_col1, #T_4559d_row30_col1, #T_4559d_row31_col1, #T_4559d_row32_col1, #T_4559d_row33_col1, #T_4559d_row34_col1, #T_4559d_row35_col1, #T_4559d_row36_col1, #T_4559d_row37_col1, #T_4559d_row48_col3, #T_4559d_row49_col3, #T_4559d_row50_col3, #T_4559d_row51_col3, #T_4559d_row52_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_4559d_row0_col1, #T_4559d_row0_col3, #T_4559d_row133_col1, #T_4559d_row134_col1, #T_4559d_row135_col1, #T_4559d_row136_col1, #T_4559d_row137_col1, #T_4559d_row138_col1, #T_4559d_row139_col1, #T_4559d_row140_col1, #T_4559d_row141_col1, #T_4559d_row142_col0, #T_4559d_row142_col1, #T_4559d_row142_col3, #T_4559d_row143_col0, #T_4559d_row143_col1, #T_4559d_row143_col3, #T_4559d_row144_col0, #T_4559d_row144_col1, #T_4559d_row144_col3, #T_4559d_row145_col0, #T_4559d_row145_col1, #T_4559d_row145_col3, #T_4559d_row146_col0, #T_4559d_row146_col1, #T_4559d_row146_col3, #T_4559d_row147_col0, #T_4559d_row147_col1, #T_4559d_row147_col3, #T_4559d_row148_col0, #T_4559d_row148_col1, #T_4559d_row148_col3, #T_4559d_row149_col0, #T_4559d_row149_col1, #T_4559d_row149_col2, #T_4559d_row149_col3, #T_4559d_row150_col0, #T_4559d_row150_col1, #T_4559d_row150_col2, #T_4559d_row150_col3, #T_4559d_row151_col0, #T_4559d_row151_col1, #T_4559d_row151_col2, #T_4559d_row151_col3, #T_4559d_row152_col0, #T_4559d_row152_col1, #T_4559d_row152_col2, #T_4559d_row152_col3, #T_4559d_row153_col0, #T_4559d_row153_col1, #T_4559d_row153_col2, #T_4559d_row153_col3, #T_4559d_row154_col0, #T_4559d_row154_col1, #T_4559d_row154_col2, #T_4559d_row154_col3, #T_4559d_row155_col0, #T_4559d_row155_col1, #T_4559d_row155_col2, #T_4559d_row155_col3, #T_4559d_row156_col0, #T_4559d_row156_col1, #T_4559d_row156_col2, #T_4559d_row156_col3, #T_4559d_row157_col0, #T_4559d_row157_col1, #T_4559d_row157_col2, #T_4559d_row157_col3, #T_4559d_row158_col0, #T_4559d_row158_col1, #T_4559d_row158_col2, #T_4559d_row158_col3, #T_4559d_row159_col0, #T_4559d_row159_col1, #T_4559d_row159_col2, #T_4559d_row159_col3, #T_4559d_row160_col0, #T_4559d_row160_col1, #T_4559d_row160_col2, #T_4559d_row160_col3, #T_4559d_row161_col0, #T_4559d_row161_col1, #T_4559d_row161_col2, #T_4559d_row161_col3, #T_4559d_row162_col0, #T_4559d_row162_col1, #T_4559d_row162_col2, #T_4559d_row162_col3, #T_4559d_row163_col0, #T_4559d_row163_col1, #T_4559d_row163_col2, #T_4559d_row163_col3, #T_4559d_row164_col0, #T_4559d_row164_col1, #T_4559d_row164_col2, #T_4559d_row164_col3, #T_4559d_row165_col0, #T_4559d_row165_col1, #T_4559d_row165_col2, #T_4559d_row165_col3, #T_4559d_row166_col0, #T_4559d_row166_col1, #T_4559d_row166_col2, #T_4559d_row166_col3, #T_4559d_row167_col0, #T_4559d_row167_col1, #T_4559d_row167_col2, #T_4559d_row167_col3, #T_4559d_row168_col0, #T_4559d_row168_col1, #T_4559d_row168_col2, #T_4559d_row168_col3, #T_4559d_row169_col0, #T_4559d_row169_col1, #T_4559d_row169_col2, #T_4559d_row169_col3, #T_4559d_row170_col0, #T_4559d_row170_col1, #T_4559d_row170_col2, #T_4559d_row170_col3, #T_4559d_row171_col0, #T_4559d_row171_col1, #T_4559d_row171_col2, #T_4559d_row171_col3, #T_4559d_row172_col0, #T_4559d_row172_col1, #T_4559d_row172_col2, #T_4559d_row172_col3, #T_4559d_row173_col0, #T_4559d_row173_col1, #T_4559d_row173_col2, #T_4559d_row173_col3, #T_4559d_row174_col0, #T_4559d_row174_col1, #T_4559d_row174_col2, #T_4559d_row174_col3, #T_4559d_row175_col0, #T_4559d_row175_col1, #T_4559d_row175_col2, #T_4559d_row175_col3, #T_4559d_row176_col0, #T_4559d_row176_col1, #T_4559d_row176_col2, #T_4559d_row176_col3, #T_4559d_row177_col0, #T_4559d_row177_col1, #T_4559d_row177_col2, #T_4559d_row177_col3, #T_4559d_row178_col0, #T_4559d_row178_col1, #T_4559d_row178_col2, #T_4559d_row178_col3, #T_4559d_row179_col0, #T_4559d_row179_col1, #T_4559d_row179_col2, #T_4559d_row179_col3, #T_4559d_row180_col0, #T_4559d_row180_col1, #T_4559d_row180_col2, #T_4559d_row180_col3, #T_4559d_row181_col0, #T_4559d_row181_col1, #T_4559d_row181_col2, #T_4559d_row181_col3, #T_4559d_row182_col0, #T_4559d_row182_col1, #T_4559d_row182_col2, #T_4559d_row182_col3, #T_4559d_row183_col0, #T_4559d_row183_col1, #T_4559d_row183_col2, #T_4559d_row183_col3, #T_4559d_row184_col0, #T_4559d_row184_col1, #T_4559d_row184_col2, #T_4559d_row184_col3, #T_4559d_row185_col0, #T_4559d_row185_col1, #T_4559d_row185_col2, #T_4559d_row185_col3, #T_4559d_row186_col0, #T_4559d_row186_col1,  ...
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4559d_row1_col2, #T_4559d_row10_col0, #T_4559d_row11_col0, #T_4559d_row12_col0, #T_4559d_row13_col0, #T_4559d_row43_col1, #T_4559d_row44_col1, #T_4559d_row45_col1, #T_4559d_row58_col3, #T_4559d_row59_col3 {
#   background-color: #fbfefc;
#   color: #000000;
# }
# #T_4559d_row1_col3, #T_4559d_row2_col3, #T_4559d_row3_col3, #T_4559d_row4_col3, #T_4559d_row5_col3, #T_4559d_row6_col3, #T_4559d_row87_col3 {
#   background-color: #c7e3f1;
#   color: #000000;
# }
# #T_4559d_row2_col2, #T_4559d_row29_col0, #T_4559d_row30_col0, #T_4559d_row31_col0, #T_4559d_row32_col0, #T_4559d_row33_col0, #T_4559d_row34_col0, #T_4559d_row35_col0, #T_4559d_row36_col0, #T_4559d_row50_col1, #T_4559d_row51_col1, #T_4559d_row52_col1, #T_4559d_row64_col3 {
#   background-color: #f6fcf8;
#   color: #000000;
# }
# #T_4559d_row3_col2, #T_4559d_row42_col0, #T_4559d_row43_col0, #T_4559d_row44_col0, #T_4559d_row45_col0, #T_4559d_row53_col1, #T_4559d_row54_col1, #T_4559d_row55_col1, #T_4559d_row56_col1, #T_4559d_row66_col3, #T_4559d_row67_col3 {
#   background-color: #f2fbf6;
#   color: #000000;
# }
# #T_4559d_row4_col0, #T_4559d_row5_col0, #T_4559d_row6_col0, #T_4559d_row7_col0, #T_4559d_row8_col0, #T_4559d_row9_col0, #T_4559d_row38_col1, #T_4559d_row39_col1, #T_4559d_row40_col1, #T_4559d_row41_col1, #T_4559d_row42_col1, #T_4559d_row53_col3, #T_4559d_row54_col3, #T_4559d_row55_col3, #T_4559d_row56_col3, #T_4559d_row57_col3 {
#   background-color: #fdfefe;
#   color: #000000;
# }
# #T_4559d_row4_col2, #T_4559d_row58_col1, #T_4559d_row68_col3, #T_4559d_row71_col3, #T_4559d_row72_col3 {
#   background-color: #effaf4;
#   color: #000000;
# }
# #T_4559d_row5_col2, #T_4559d_row60_col1 {
#   background-color: #ebf9f3;
#   color: #000000;
# }
# #T_4559d_row6_col2, #T_4559d_row61_col1, #T_4559d_row62_col1 {
#   background-color: #e7f8f1;
#   color: #000000;
# }
# #T_4559d_row7_col2 {
#   background-color: #e3f6f0;
#   color: #000000;
# }
# #T_4559d_row7_col3, #T_4559d_row8_col3, #T_4559d_row9_col3, #T_4559d_row10_col3, #T_4559d_row11_col3, #T_4559d_row15_col2 {
#   background-color: #c8e4f0;
#   color: #000000;
# }
# #T_4559d_row8_col2, #T_4559d_row75_col3 {
#   background-color: #def4ef;
#   color: #000000;
# }
# #T_4559d_row9_col2, #T_4559d_row67_col1 {
#   background-color: #dbf3ef;
#   color: #000000;
# }
# #T_4559d_row10_col2, #T_4559d_row70_col1 {
#   background-color: #d6f0ef;
#   color: #000000;
# }
# #T_4559d_row11_col2, #T_4559d_row71_col1 {
#   background-color: #d3eeef;
#   color: #000000;
# }
# #T_4559d_row12_col2 {
#   background-color: #cfebef;
#   color: #000000;
# }
# #T_4559d_row12_col3, #T_4559d_row13_co

# %%
#Top 10 dates with the highest number of active cases

top_10_active_cases = covid_df.groupby(by = "Date").max()[["Active Cases"]].sort_values(by = ["Active Cases"], ascending = False).reset_index()

# %%
#Creating figure object 
fig = plt.figure(figsize = (16,9))

# %%
#Creating plot 
plt.title("Top 10 dates with the highest recorded number of active cases", size = 25)
# Out:
# Text(0.5, 1.0, 'Top 10 dates with the highest recorded number of active cases')

# %%
#Defining axis using data
ax = sns.barplot(data = top_10_active_cases.iloc[:10], y = "Active Cases", x = "Date", linewidth = 2, edgecolor = "black")

# %%
#All combined

top_10_active_cases = covid_df.groupby(by = "Date").max()[["Active Cases"]].sort_values(by = ["Active Cases"], ascending = False).reset_index()
fig = plt.figure(figsize = (16,9))
plt.title("Top 10 dates with the highest recorded number of active cases", size = 25)
ax = sns.barplot(data = top_10_active_cases.iloc[:10], y = "Active Cases", x = "Date", linewidth = 2, edgecolor = "black")


plt.xlabel("Date")
plt.ylabel("Total Active Cases")
plt.show()

# %%
#Top 10 dates with highest recorded deaths

top_10_deaths = covid_df.groupby(by = "Date").max()[["Deaths"]].sort_values(by = "Deaths", ascending = False).reset_index()

fig = plt.figure(figsize=(18,5))

plt.title("Top 10 dates with highest recorded deaths", size = 25)

ax = sns.barplot(data = top_10_deaths.iloc[:10], y = "Deaths", x = "Date", linewidth = 2, edgecolor = "black")

plt.xlabel("Date")
plt.ylabel("Total Deaths")
plt.show()

# %%
#Growth trend of the top 5 active cases of Covid in Scotland

fig = plt.figure(figsize = (12,6))

ax = sns.lineplot(data = covid_df[covid_df["Date"].isin(["2020-07-31", "2020-07-23", "2020-07-16", "2020-07-17", "2020-07-18", "2020-07-19"])], x = "Date", y = "Active Cases")

ax.set_title("Top 5 Active Cases of Covid in Scotland", size = 16)
# Out:
# Text(0.5, 1.0, 'Top 5 Active Cases of Covid in Scotland')

# %%
vaccine_df.head()
# Out:
#    _id        Date    Country                  Product  Population    Dose  \
# 0    1  2020-12-08  S92000003  AstraZeneca (Vaxzevria)         NaN  Dose 1
# 1    2  2020-12-08  S92000003  AstraZeneca (Vaxzevria)         NaN  Dose 2
# 2    3  2020-12-08  S92000003  AstraZeneca (Vaxzevria)         NaN  Dose 3
# 3    4  2020-12-08  S92000003       Moderna (Spikevax)         NaN  Dose 1
# 4    5  2020-12-08  S92000003       Moderna (Spikevax)         NaN  Dose 2
#
#    NumberVaccinated  PercentCoverage  CumulativeNumberVaccinated  \
# 0                14              NaN                          14
# 1                 0              NaN                           0
# 2                 0              NaN                           0
# 3                 0              NaN                           0
# 4                 0              NaN                           0
#
#    CumulativePercentCoverage           AgeBand
# 0                        NaN  All vaccinations
# 1                        NaN  All vaccinations
# 2                        NaN  All vaccinations
# 3                        NaN  All vaccinations
# 4                        NaN  All vaccinations

# %%
#Incorporating rename function
vaccine_df.rename(columns = {"Date" : "Vaccine Date"}, inplace = True)
vaccine_df.head(10)
# Out:
#    _id Vaccine Date    Country                      Product  Population  \
# 0    1   2020-12-08  S92000003      AstraZeneca (Vaxzevria)         NaN
# 1    2   2020-12-08  S92000003      AstraZeneca (Vaxzevria)         NaN
# 2    3   2020-12-08  S92000003      AstraZeneca (Vaxzevria)         NaN
# 3    4   2020-12-08  S92000003           Moderna (Spikevax)         NaN
# 4    5   2020-12-08  S92000003           Moderna (Spikevax)         NaN
# 5    6   2020-12-08  S92000003           Moderna (Spikevax)         NaN
# 6    7   2020-12-08  S92000003  Pfizer BioNTech (Comirnaty)         NaN
# 7    8   2020-12-08  S92000003  Pfizer BioNTech (Comirnaty)         NaN
# 8    9   2020-12-08  S92000003  Pfizer BioNTech (Comirnaty)         NaN
# 9   10   2020-12-08  S92000003                        Total         NaN
#
#      Dose  NumberVaccinated  PercentCoverage  CumulativeNumberVaccinated  \
# 0  Dose 1                14              NaN                          14
# 1  Dose 2                 0              NaN                           0
# 2  Dose 3                 0              NaN                           0
# 3  Dose 1                 0              NaN                           0
# 4  Dose 2                 0              NaN                           0
# 5  Dose 3                 0              NaN                           0
# 6  Dose 1              1934              NaN                        1934
# 7  Dose 2                 0              NaN                           0
# 8  Dose 3                 0              NaN                           0
# 9  Dose 1              1948              NaN                        1948
#
#    CumulativePercentCoverage           AgeBand
# 0                        NaN  All vaccinations
# 1                        NaN  All vaccinations
# 2                        NaN  All vaccinations
# 3                        NaN  All vaccinations
# 4                        NaN  All vaccinations
# 5                        NaN  All vaccinations
# 6                        NaN  All vaccinations
# 7                        NaN  All vaccinations
# 8                        NaN  All vaccinations
# 9                        NaN  All vaccinations

# %%
vaccine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         504 non-null    int64
#  1   Vaccine Date                504 non-null    object
#  2   Country                     504 non-null    object
#  3   Product                     504 non-null    object
#  4   Population                  216 non-null    float64
#  5   Dose                        504 non-null    object
#  6   NumberVaccinated            504 non-null    int64
#  7   PercentCoverage             216 non-null    float64
#  8   CumulativeNumberVaccinated  504 non-null    int64
#  9   CumulativePercentCoverage   216 non-null    float64
#  10  AgeBand                     504 non-null    object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 43.4+ KB

# %%
#Checks which values are null/not given. 0=notnull, have value=null
vaccine_df.isnull().sum()
# Out:
# _id                             0
# Vaccine Date                    0
# Country                         0
# Product                         0
# Population                    288
# Dose                            0
# NumberVaccinated                0
# PercentCoverage               288
# CumulativeNumberVaccinated      0
# CumulativePercentCoverage     288
# AgeBand                         0
# dtype: int64

# %%
#Drop/remove columns
vaccination = vaccine_df.drop(columns = ["Country", "_id", "PercentCoverage", "CumulativeNumberVaccinated", "CumulativePercentCoverage"], axis = 1)
vaccination.head(10)
# Out:
#   Vaccine Date                      Product  Population    Dose  \
# 0   2020-12-08      AstraZeneca (Vaxzevria)         NaN  Dose 1
# 1   2020-12-08      AstraZeneca (Vaxzevria)         NaN  Dose 2
# 2   2020-12-08      AstraZeneca (Vaxzevria)         NaN  Dose 3
# 3   2020-12-08           Moderna (Spikevax)         NaN  Dose 1
# 4   2020-12-08           Moderna (Spikevax)         NaN  Dose 2
# 5   2020-12-08           Moderna (Spikevax)         NaN  Dose 3
# 6   2020-12-08  Pfizer BioNTech (Comirnaty)         NaN  Dose 1
# 7   2020-12-08  Pfizer BioNTech (Comirnaty)         NaN  Dose 2
# 8   2020-12-08  Pfizer BioNTech (Comirnaty)         NaN  Dose 3
# 9   2020-12-08                        Total         NaN  Dose 1
#
#    NumberVaccinated           AgeBand
# 0                14  All vaccinations
# 1                 0  All vaccinations
# 2                 0  All vaccinations
# 3                 0  All vaccinations
# 4                 0  All vaccinations
# 5                 0  All vaccinations
# 6              1934  All vaccinations
# 7                 0  All vaccinations
# 8                 0  All vaccinations
# 9              1948  All vaccinations

# %%
#Dates with the most number of vaccination
max_vac = vaccination.groupby("Vaccine Date")["NumberVaccinated"].sum().to_frame("NumberVaccinated")
max_vac = max_vac.sort_values("NumberVaccinated", ascending = False)[:5]
max_vac
# Out:
#               NumberVaccinated
# Vaccine Date
# 2020-12-22               56100
# 2020-12-23               48400
# 2020-12-21               45460
# 2020-12-18               40311
# 2020-12-30               36992

# %%
#Plot, Axis Data, and Figure objects combined
fig = plt.figure(figsize=(10,5))
plt.title("Top 5 Dates with the Most Number of Vaccination", size = 20)
ax = sns.barplot(data = max_vac.iloc[:10], y = max_vac.NumberVaccinated, x = max_vac.index, linewidth = 2, edgecolor = "black")
plt.xlabel("Date")
plt.ylabel("Vaccination")
plt.show()

# %%
#Dates with the least number of vaccination
min_vac = vaccination.groupby("Vaccine Date")["NumberVaccinated"].sum().to_frame("NumberVaccinated")
min_vac = min_vac.sort_values("NumberVaccinated", ascending = True)[:5]
min_vac

fig = plt.figure(figsize=(10,5))
plt.title("Top 5 Dates with the Least Number of Vaccination", size = 20)
ax = sns.barplot(data = min_vac.iloc[:10], y = min_vac.NumberVaccinated, x = min_vac.index, linewidth = 2, edgecolor = "black")
plt.xlabel("Date")
plt.ylabel("Vaccination")
plt.show()
